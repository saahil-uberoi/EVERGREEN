# %% [markdown]
# # Extract table from PDF report

# %%
# comment out this cell if tabula has not been installed
# !pip install tabula

# %%
# import the require package
import tabula
# check the version
tabula.environment_info()
# Out:
# Python version:
#     3.7.4 (default, Aug 13 2019, 15:17:50)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Java version:
#     java version "1.8.0_201"
# Java(TM) SE Runtime Environment (build 1.8.0_201-b09)
# Java HotSpot(TM) 64-Bit Server VM (build 25.201-b09, mixed mode)
# tabula-py version: 2.1.1
# platform: Darwin-19.4.0-x86_64-i386-64bit
# uname:
#     uname_result(system='Darwin', node='JasperLiangs-MacBook-Pro.local', release='19.4.0', version='Darwin Kernel Version 19.4.0: Wed Mar  4 22:28:40 PST 2020; root:xnu-6153.101.6~15/RELEASE_X86_64', machine='x86_64', processor='i386')
# linux_distribution: ('Darwin', '19.4.0', '')
# mac_ver: ('10.15.4', ('', '', ''), 'x86_64')

# %%
import tabula
# pdf_path = "https://github.com/chezou/tabula-py/raw/master/tests/resources/data.pdf"

dfs = tabula.read_pdf('plants list.pdf', stream=True, pages = [9,10],multiple_tables=False)
# Out:
# Got stderr: Sep 16, 2020 5:18:28 AM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 0 (CID 0000) in font XSDBPH+HelveticaNeue-Light
# Sep 16, 2020 5:18:28 AM org.apache.pdfbox.rendering.CIDType0Glyph2D getPathForCharacterCode
# WARNING: No glyph for 0 (CID 0000) in font XSDBPH+HelveticaNeue-Light

# %%
# get the table from pdf
initial_table = dfs[0]
initial_table.head(10)
# Out:
#   Insects    Synemon plana golden sun moth  \
# 0     NaN              NaN             NaN
# 1     NaN              NaN             NaN
# 2     NaN              NaN             NaN
# 3     NaN              NaN             NaN
# 4     NaN              NaN             NaN
# 5     NaN              NaN             NaN
# 6     NaN              NaN             NaN
# 7     NaN              NaN             NaN
# 8  Plants  Carex tasmanica     curly sedge
# 9     NaN              NaN             NaN
#
#                A day flying moth about 3cm  Critically
# 0            wingspan. Formerly widespread  Endangered
# 1           through New South Wales (NSW),         NaN
# 2  Australian Capital Territory (ACT), Vic         NaN
# 3        and South Australia (SA), now has         NaN
# 4          a highly reduced and fragmented         NaN
# 5      distribution and considered extinct         NaN
# 6        in SA. Inhabits natural temperate         NaN
# 7          grassland and grassy woodlands.         NaN
# 8        From Vic and Tasmania (Tas) only.  Vulnerable
# 9         Usually associated with drainage         NaN

# %%
# exclude the introduction part
initial_table.drop(range(8),inplace=True)
initial_table
# Out:
#    Insects         Synemon plana    golden sun moth  \
# 8   Plants       Carex tasmanica        curly sedge
# 9      NaN                   NaN                NaN
# 10     NaN                   NaN                NaN
# 11     NaN         Cullen parvum    small scurf-pea
# 12     NaN                   NaN                NaN
# ..     ...                   ...                ...
# 94     NaN                   NaN                NaN
# 95     NaN  Xerochrysum palustre  swamp everlasting
# 96     NaN                   NaN                NaN
# 97     NaN                   NaN                NaN
# 98     NaN                   NaN                NaN
#
#                A day flying moth about 3cm  Critically
# 8        From Vic and Tasmania (Tas) only.  Vulnerable
# 9         Usually associated with drainage         NaN
# 10                       lines or marshes.         NaN
# 11            Only occurs in Vic and SA in  Endangered
# 12     grassland and grassy woodland sites         NaN
# ..                                     ...         ...
# 94                       spring and summer         NaN
# 95        Occurs in southern Vic and a few  Vulnerable
# 96  sites in northern Tas. Perennial herb,         NaN
# 97       flowering November to March dying         NaN
# 98                     off in late summer.         NaN
#
# [91 rows x 5 columns]

# %%
# rename to columns for name convinient
initial_table.columns=['SPECIES','SCIENTIFIC_NAME','COMMON_NAME','NOTES','EPBC_ACT_STATUS']
initial_table['SPECIES'] = 'Flora'

# %%
# reset the index and replace the missing value inside
initial_table = initial_table.reset_index(drop=True)
initial_table = initial_table.fillna("")
initial_table
# Out:
#    SPECIES       SCIENTIFIC_NAME        COMMON_NAME  \
# 0    Flora       Carex tasmanica        curly sedge
# 1    Flora
# 2    Flora
# 3    Flora         Cullen parvum    small scurf-pea
# 4    Flora
# ..     ...                   ...                ...
# 86   Flora
# 87   Flora  Xerochrysum palustre  swamp everlasting
# 88   Flora
# 89   Flora
# 90   Flora
#
#                                      NOTES EPBC_ACT_STATUS
# 0        From Vic and Tasmania (Tas) only.      Vulnerable
# 1         Usually associated with drainage
# 2                        lines or marshes.
# 3             Only occurs in Vic and SA in      Endangered
# 4      grassland and grassy woodland sites
# ..                                     ...             ...
# 86                       spring and summer
# 87        Occurs in southern Vic and a few      Vulnerable
# 88  sites in northern Tas. Perennial herb,
# 89       flowering November to March dying
# 90                     off in late summer.
#
# [91 rows x 5 columns]

# %%
# check the format of the non-numeric column(s) 
initial_table['NOTES'].tolist()
# Out:
# ['From Vic and Tasmania (Tas) only.',
#  'Usually associated with drainage',
#  'lines or marshes.',
#  'Only occurs in Vic and SA in',
#  'grassland and grassy woodland sites',
#  'which get irregular flooding. Flowers',
#  'between October and February. Dies',
#  'back, so not visible, in winter.',
#  'Summer flowering large herb up',
#  'to 5m wide with flower spikes to',
#  '90cm. Current distribution restricted',
#  'and fragmented, some populations',
#  'occurring in urban areas.',
#  'Known only from Vic on basalt',
#  'plains north and west of Melbourne.',
#  'Flowering in September and',
#  'October.',
#  'Only one known remaining',
#  'population to the north of',
#  'Melbourne. Flowering mid-October',
#  'to early November. Pollination reliant',
#  'on native bees.',
#  'Known from southern NSW, Vic and',
#  'SA. Flowering November to February',
#  'and fruits may take up to 12 months',
#  'to mature.',
#  'Occurs in Tas, a single location in',
#  'SA and is spread throughout Vic but',
#  'only six known viable populations.',
#  'Grows mostly in grasslands and',
#  'grassy woodlands, flowering in',
#  'September to December.',
#  'Endemic to south-central and south-',
#  'western Victoria. Tufted annual grass',
#  'to 70cm high. Previously known as',
#  'Agrostis adamsonii.',
#  'Thought to be extinct in NSW.',
#  'Occurs in the south west of Vic but',
#  'only a few known stands. Branched',
#  'perennial herb to 30cm high. Arises',
#  'from underground rootstock and',
#  'is only visible during the spring-',
#  'summer growth period.',
#  'Vic distribution from only three areas',
#  'in central Vic. Perennial herb to',
#  '50cm high flowering from December',
#  'to February.',
#  'Known from NSW, ACT, Vic and',
#  'Tas. Distribution for Vic is restricted',
#  'to south-western Vic but was',
#  'previously more widely spread.',
#  'Mounding perennial straw daisy',
#  'to 30cm high, flowers in spring to',
#  'summer.',
#  'Endemic to south-western and',
#  'central Vic. Stunted shrub to 30cm,',
#  'flowers in April to August. If present',
#  'should be visible throughout the year.',
#  'Endemic to south-western Vic,',
#  'known from only a few sites. Orchid',
#  'to 60cm high, flowering December',
#  'to February.',
#  'Distributed in Vic and far south-',
#  'eastern SA. Seasonal perennial',
#  'orchid to 60cm, flowering October to',
#  'December.',
#  'Known only from western Vic.',
#  'Slender orchid to 25cm, flowering',
#  'October and November.',
#  'Endemic to central Vic from only',
#  'a few populations. Flowering',
#  'November to January.',
#  'Distributed in south-eastern NSW',
#  'and ACT and south-western Vic,',
#  'mostly in grasslands. Flowering',
#  'October to January.',
#  'Occurs in south-eastern SA and',
#  'south-western Vic. Shrub to 70cm,',
#  'flowering September to November',
#  'Occurs in south-eastern SA and',
#  'western Vic.',
#  '',
#  'Occurs in south-eastern QLD,',
#  'eastern NSW and eastern Vic.',
#  'Formerly occurred in western Vic.',
#  'Perennial herb to 40cm, flowering',
#  'spring and summer',
#  'Occurs in southern Vic and a few',
#  'sites in northern Tas. Perennial herb,',
#  'flowering November to March dying',
#  'off in late summer.']

# %%
# combine all the seperate lines in one text
for i in range(len(initial_table)-1,0,-1):
    if initial_table.loc[i,'EPBC_ACT_STATUS'] == "":
        # scientific name
        s_name = initial_table.loc[i,'SCIENTIFIC_NAME']
        pre_s_name = initial_table.loc[i-1,'SCIENTIFIC_NAME']
        initial_table.loc[i-1,'SCIENTIFIC_NAME'] = pre_s_name + " " + s_name
        # common name
        c_name = initial_table.loc[i,'COMMON_NAME']
        pre_c_name = initial_table.loc[i-1,'COMMON_NAME']
        initial_table.loc[i-1,'COMMON_NAME'] = pre_c_name + " " + c_name
        # text part
        text = initial_table.loc[i,'NOTES']
        pre_text = initial_table.loc[i-1,'NOTES']
        initial_table.loc[i-1,'NOTES'] = pre_text + " " + text

# %%
# check the redundant spaces
initial_table.loc[88,"SCIENTIFIC_NAME"] in [""," ","  ","   "]
# Out:
# True

# %%
# remove all the redundant spaces and invalid rows
flora = initial_table.drop(initial_table[initial_table.EPBC_ACT_STATUS.isin([""," ","  ","   "])].index)
flora = flora.reset_index(drop=True)
flora
# Out:
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Carex tasmanica
# 1    Flora                             Cullen parvum
# 2    Flora                           Dianella amoena
# 3    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 4    Flora                     Diuris fragrantissima
# 5    Flora                         Dodonaea procumbens
# 6    Flora                       Glycine latrobeana
# 7    Flora                     Lachnagrostis adamsonii
# 8    Flora                    Lepidium aschersonii
# 9    Flora                     Lepidium hyssopifolium
# 10   Flora      Leucochrysum albicans var. tricolor
# 11   Flora                            Pimelea spinescens
# 12   Flora                           subsp. spinescens
# 13   Flora                  Prasophyllum diversiflorum
# 14   Flora                      Prasophyllum frenchii
# 15   Flora                      Prasophyllum suaveolens
# 16   Flora                       Pterostylis basaltica
# 17   Flora                 Rutidosis leptorrhynchoides
# 18   Flora                         Senecio macrocarpus
# 19   Flora                         Senecio psilocarpus
# 20   Flora                          Thesium australe
# 21   Flora                       Xerochrysum palustre
#
#                                           COMMON_NAME  \
# 0                                       curly sedge
# 1                                 small scurf-pea
# 2                                matted flax-lily
# 3            small golden moths, early golden moths
# 4   sunshine diuris, white diuris, fragrant double...
# 5                                trailing hop-bush
# 6                   clover glycine, purple clover
# 7                            adamson’s blown- grass
# 8                            spiny pepper-cress
# 9                              basalt pepper-cress
# 10                                 hoary sunray
# 11                          plains rice-flower, spiny
# 12                      rice-flower, prickly pimelea
# 13                               gorae leek-orchid
# 14  maroon leek-orchid, slaty leek-orchid, stout l...
# 15                             fragrant leek-orchid
# 16                                 basalt greenhood
# 17                              button wrinklewort
# 18       large-fruit groundsel, large-fruit fireweed
# 19           swamp fireweed, smooth-fruited groundsel
# 20                      austral toadflax, toadflax
# 21                               swamp everlasting
#
#                                                 NOTES EPBC_ACT_STATUS
# 0   From Vic and Tasmania (Tas) only. Usually asso...      Vulnerable
# 1   Only occurs in Vic and SA in grassland and gra...      Endangered
# 2   Summer flowering large herb up to 5m wide with...      Endangered
# 3   Known only from Vic on basalt plains north and...      Endangered
# 4   Only one known remaining population to the nor...      Endangered
# 5   Known from southern NSW, Vic and SA. Flowering...      Vulnerable
# 6   Occurs in Tas, a single location in SA and is ...      Vulnerable
# 7   Endemic to south-central and south- western Vi...      Endangered
# 8   Thought to be extinct in NSW. Occurs in the so...      Vulnerable
# 9   Vic distribution from only three areas in cent...      Endangered
# 10  Known from NSW, ACT, Vic and Tas. Distribution...      Endangered
# 11                       Endemic to south-western and      Critically
# 12  central Vic. Stunted shrub to 30cm, flowers in...      Endangered
# 13  Endemic to south-western Vic, known from only ...      Endangered
# 14  Distributed in Vic and far south- eastern SA. ...      Endangered
# 15  Known only from western Vic. Slender orchid to...      Endangered
# 16  Endemic to central Vic from only a few populat...      Endangered
# 17  Distributed in south-eastern NSW and ACT and s...      Endangered
# 18  Occurs in south-eastern SA and south-western V...      Vulnerable
# 19       Occurs in south-eastern SA and western Vic.       Vulnerable
# 20  Occurs in south-eastern QLD, eastern NSW and e...      Vulnerable
# 21  Occurs in southern Vic and a few sites in nort...      Vulnerable

# %%
# fix the format errors in the name columns
cd_sname = flora.loc[11,'SCIENTIFIC_NAME']
cd_cname = flora.loc[11,'COMMON_NAME']
cd_note = flora.loc[11,'NOTES']
cd_status = flora.loc[11,'EPBC_ACT_STATUS']
flora.loc[11,'SCIENTIFIC_NAME'] = cd_sname + " " + flora.loc[12,'SCIENTIFIC_NAME']
flora.loc[11,'COMMON_NAME'] = cd_cname + " " + flora.loc[12,'COMMON_NAME']
flora.loc[11,'NOTES'] = cd_note + " " + flora.loc[12,'NOTES']
flora.loc[11,'EPBC_ACT_STATUS'] = cd_status + " " + flora.loc[12,'EPBC_ACT_STATUS']
flora = flora.drop(12)
flora = flora.reset_index(drop=True)
flora
# Out:
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Carex tasmanica
# 1    Flora                             Cullen parvum
# 2    Flora                           Dianella amoena
# 3    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 4    Flora                     Diuris fragrantissima
# 5    Flora                         Dodonaea procumbens
# 6    Flora                       Glycine latrobeana
# 7    Flora                     Lachnagrostis adamsonii
# 8    Flora                    Lepidium aschersonii
# 9    Flora                     Lepidium hyssopifolium
# 10   Flora      Leucochrysum albicans var. tricolor
# 11   Flora        Pimelea spinescens subsp. spinescens
# 12   Flora                  Prasophyllum diversiflorum
# 13   Flora                      Prasophyllum frenchii
# 14   Flora                      Prasophyllum suaveolens
# 15   Flora                       Pterostylis basaltica
# 16   Flora                 Rutidosis leptorrhynchoides
# 17   Flora                         Senecio macrocarpus
# 18   Flora                         Senecio psilocarpus
# 19   Flora                          Thesium australe
# 20   Flora                       Xerochrysum palustre
#
#                                           COMMON_NAME  \
# 0                                       curly sedge
# 1                                 small scurf-pea
# 2                                matted flax-lily
# 3            small golden moths, early golden moths
# 4   sunshine diuris, white diuris, fragrant double...
# 5                                trailing hop-bush
# 6                   clover glycine, purple clover
# 7                            adamson’s blown- grass
# 8                            spiny pepper-cress
# 9                              basalt pepper-cress
# 10                                 hoary sunray
# 11  plains rice-flower, spiny rice-flower, prickly...
# 12                               gorae leek-orchid
# 13  maroon leek-orchid, slaty leek-orchid, stout l...
# 14                             fragrant leek-orchid
# 15                                 basalt greenhood
# 16                              button wrinklewort
# 17       large-fruit groundsel, large-fruit fireweed
# 18           swamp fireweed, smooth-fruited groundsel
# 19                      austral toadflax, toadflax
# 20                               swamp everlasting
#
#                                                 NOTES        EPBC_ACT_STATUS
# 0   From Vic and Tasmania (Tas) only. Usually asso...             Vulnerable
# 1   Only occurs in Vic and SA in grassland and gra...             Endangered
# 2   Summer flowering large herb up to 5m wide with...             Endangered
# 3   Known only from Vic on basalt plains north and...             Endangered
# 4   Only one known remaining population to the nor...             Endangered
# 5   Known from southern NSW, Vic and SA. Flowering...             Vulnerable
# 6   Occurs in Tas, a single location in SA and is ...             Vulnerable
# 7   Endemic to south-central and south- western Vi...             Endangered
# 8   Thought to be extinct in NSW. Occurs in the so...             Vulnerable
# 9   Vic distribution from only three areas in cent...             Endangered
# 10  Known from NSW, ACT, Vic and Tas. Distribution...             Endangered
# 11  Endemic to south-western and central Vic. Stun...  Critically Endangered
# 12  Endemic to south-western Vic, known from only ...             Endangered
# 13  Distributed in Vic and far south- eastern SA. ...             Endangered
# 14  Known only from western Vic. Slender orchid to...             Endangered
# 15  Endemic to central Vic from only a few populat...             Endangered
# 16  Distributed in south-eastern NSW and ACT and s...             Endangered
# 17  Occurs in south-eastern SA and south-western V...             Vulnerable
# 18       Occurs in south-eastern SA and western Vic.              Vulnerable
# 19  Occurs in south-eastern QLD, eastern NSW and e...             Vulnerable
# 20  Occurs in southern Vic and a few sites in nort...             Vulnerable

# %%
# make the name format consist
flora.loc[3,'COMMON_NAME'] = 'clumping golden moths'
flora['COMMON_NAME'] = flora['COMMON_NAME'].str.title()
flora
# Out:
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Carex tasmanica
# 1    Flora                             Cullen parvum
# 2    Flora                           Dianella amoena
# 3    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 4    Flora                     Diuris fragrantissima
# 5    Flora                         Dodonaea procumbens
# 6    Flora                       Glycine latrobeana
# 7    Flora                     Lachnagrostis adamsonii
# 8    Flora                    Lepidium aschersonii
# 9    Flora                     Lepidium hyssopifolium
# 10   Flora      Leucochrysum albicans var. tricolor
# 11   Flora        Pimelea spinescens subsp. spinescens
# 12   Flora                  Prasophyllum diversiflorum
# 13   Flora                      Prasophyllum frenchii
# 14   Flora                      Prasophyllum suaveolens
# 15   Flora                       Pterostylis basaltica
# 16   Flora                 Rutidosis leptorrhynchoides
# 17   Flora                         Senecio macrocarpus
# 18   Flora                         Senecio psilocarpus
# 19   Flora                          Thesium australe
# 20   Flora                       Xerochrysum palustre
#
#                                           COMMON_NAME  \
# 0                                       Curly Sedge
# 1                                 Small Scurf-Pea
# 2                                Matted Flax-Lily
# 3                               Clumping Golden Moths
# 4   Sunshine Diuris, White Diuris, Fragrant Double...
# 5                                Trailing Hop-Bush
# 6                   Clover Glycine, Purple Clover
# 7                            Adamson’S Blown- Grass
# 8                            Spiny Pepper-Cress
# 9                              Basalt Pepper-Cress
# 10                                 Hoary Sunray
# 11  Plains Rice-Flower, Spiny Rice-Flower, Prickly...
# 12                               Gorae Leek-Orchid
# 13  Maroon Leek-Orchid, Slaty Leek-Orchid, Stout L...
# 14                             Fragrant Leek-Orchid
# 15                                 Basalt Greenhood
# 16                              Button Wrinklewort
# 17       Large-Fruit Groundsel, Large-Fruit Fireweed
# 18           Swamp Fireweed, Smooth-Fruited Groundsel
# 19                      Austral Toadflax, Toadflax
# 20                               Swamp Everlasting
#
#                                                 NOTES        EPBC_ACT_STATUS
# 0   From Vic and Tasmania (Tas) only. Usually asso...             Vulnerable
# 1   Only occurs in Vic and SA in grassland and gra...             Endangered
# 2   Summer flowering large herb up to 5m wide with...             Endangered
# 3   Known only from Vic on basalt plains north and...             Endangered
# 4   Only one known remaining population to the nor...             Endangered
# 5   Known from southern NSW, Vic and SA. Flowering...             Vulnerable
# 6   Occurs in Tas, a single location in SA and is ...             Vulnerable
# 7   Endemic to south-central and south- western Vi...             Endangered
# 8   Thought to be extinct in NSW. Occurs in the so...             Vulnerable
# 9   Vic distribution from only three areas in cent...             Endangered
# 10  Known from NSW, ACT, Vic and Tas. Distribution...             Endangered
# 11  Endemic to south-western and central Vic. Stun...  Critically Endangered
# 12  Endemic to south-western Vic, known from only ...             Endangered
# 13  Distributed in Vic and far south- eastern SA. ...             Endangered
# 14  Known only from western Vic. Slender orchid to...             Endangered
# 15  Endemic to central Vic from only a few populat...             Endangered
# 16  Distributed in south-eastern NSW and ACT and s...             Endangered
# 17  Occurs in south-eastern SA and south-western V...             Vulnerable
# 18       Occurs in south-eastern SA and western Vic.              Vulnerable
# 19  Occurs in south-eastern QLD, eastern NSW and e...             Vulnerable
# 20  Occurs in southern Vic and a few sites in nort...             Vulnerable

# %% [markdown]
# # Data cleaning

# %%
# select the index of flowering plants
f_count = 0
flower = []
for i in flora.index:
    if "flowering" in flora.loc[i,'NOTES'].lower().split() or "flowers" in flora.loc[i,'NOTES'].lower().split():
        f_count+=1
        flower.append(i)
print(f_count)
print(flower)
# Out:
# 17
# [1, 2, 3, 4, 5, 6, 9, 10, 11, 12, 13, 14, 15, 16, 17, 19, 20]

# %%
# select the index of endangered or critically endangered plants
v_count = 0
endangered = []
for j in flora.index:
    if flora.loc[j,'EPBC_ACT_STATUS']!="Vulnerable":
        v_count+=1
        endangered.append(j)
print(v_count)
print(endangered)
# Out:
# 13
# [1, 2, 3, 4, 7, 9, 10, 11, 12, 13, 14, 15, 16]

# %%
# extract the endangered plants inside the table
target_index = list(set(endangered).intersection(flower))
target_index
# Out:
# [1, 2, 3, 4, 9, 10, 11, 12, 13, 14, 15, 16]

# %%
flower_index = flora.index.isin(target_index)
flora.drop(flora[~flower_index].index,inplace=True)
flora = flora.reset_index(drop=True)
flora
# Out:
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Cullen parvum
# 1    Flora                           Dianella amoena
# 2    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 3    Flora                     Diuris fragrantissima
# 4    Flora                     Lepidium hyssopifolium
# 5    Flora      Leucochrysum albicans var. tricolor
# 6    Flora        Pimelea spinescens subsp. spinescens
# 7    Flora                  Prasophyllum diversiflorum
# 8    Flora                      Prasophyllum frenchii
# 9    Flora                      Prasophyllum suaveolens
# 10   Flora                       Pterostylis basaltica
# 11   Flora                 Rutidosis leptorrhynchoides
#
#                                           COMMON_NAME  \
# 0                                 Small Scurf-Pea
# 1                                Matted Flax-Lily
# 2                               Clumping Golden Moths
# 3   Sunshine Diuris, White Diuris, Fragrant Double...
# 4                              Basalt Pepper-Cress
# 5                                  Hoary Sunray
# 6   Plains Rice-Flower, Spiny Rice-Flower, Prickly...
# 7                                Gorae Leek-Orchid
# 8   Maroon Leek-Orchid, Slaty Leek-Orchid, Stout L...
# 9                              Fragrant Leek-Orchid
# 10                                 Basalt Greenhood
# 11                              Button Wrinklewort
#
#                                                 NOTES        EPBC_ACT_STATUS
# 0   Only occurs in Vic and SA in grassland and gra...             Endangered
# 1   Summer flowering large herb up to 5m wide with...             Endangered
# 2   Known only from Vic on basalt plains north and...             Endangered
# 3   Only one known remaining population to the nor...             Endangered
# 4   Vic distribution from only three areas in cent...             Endangered
# 5   Known from NSW, ACT, Vic and Tas. Distribution...             Endangered
# 6   Endemic to south-western and central Vic. Stun...  Critically Endangered
# 7   Endemic to south-western Vic, known from only ...             Endangered
# 8   Distributed in Vic and far south- eastern SA. ...             Endangered
# 9   Known only from western Vic. Slender orchid to...             Endangered
# 10  Endemic to central Vic from only a few populat...             Endangered
# 11  Distributed in south-eastern NSW and ACT and s...             Endangered

# %% [markdown]
# # Data wrangling

# %%
import re

# %%
# extract the flowering period mentioned in the descriptions
flora["FLOWERING_PERIOD"] = ""
flora["HABITAT"] = "Tussock Plains - lowland tussock grassland"
for i in flora.index:
    note = flora.loc[i,"NOTES"].lower()
    # add flowering period
    period = re.search(r'(flower[\w\W]*?)(?:[\.\,])', note).group(1)
    flora.loc[i,"FLOWERING_PERIOD"] = period.capitalize()
    # add habitat
    woodland = re.findall(r'woodland.*?', note)
    if len(woodland) >= 1:
        flora.loc[i,"HABITAT"] = "Woodland - Grassy Eucalypt Woodland"
    elif "basalt" in flora.loc[i,"COMMON_NAME"].lower().split() or "basalt" in flora.loc[i,"NOTES"].lower().split():
        flora.loc[i,"HABITAT"] = "Rocky areas - Western (Basalt) Plains"
flora
# Out:
# 1
# 2
# 2
# 2
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Cullen parvum
# 1    Flora                           Dianella amoena
# 2    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 3    Flora                     Diuris fragrantissima
# 4    Flora                     Lepidium hyssopifolium
# 5    Flora      Leucochrysum albicans var. tricolor
# 6    Flora        Pimelea spinescens subsp. spinescens
# 7    Flora                  Prasophyllum diversiflorum
# 8    Flora                      Prasophyllum frenchii
# 9    Flora                      Prasophyllum suaveolens
# 10   Flora                       Pterostylis basaltica
# 11   Flora                 Rutidosis leptorrhynchoides
#
#                                           COMMON_NAME  \
# 0                                 Small Scurf-Pea
# 1                                Matted Flax-Lily
# 2                               Clumping Golden Moths
# 3   Sunshine Diuris, White Diuris, Fragrant Double...
# 4                              Basalt Pepper-Cress
# 5                                  Hoary Sunray
# 6   Plains Rice-Flower, Spiny Rice-Flower, Prickly...
# 7                                Gorae Leek-Orchid
# 8   Maroon Leek-Orchid, Slaty Leek-Orchid, Stout L...
# 9                              Fragrant Leek-Orchid
# 10                                 Basalt Greenhood
# 11                              Button Wrinklewort
#
#                                                 NOTES        EPBC_ACT_STATUS  \
# 0   Only occurs in Vic and SA in grassland and gra...             Endangered
# 1   Summer flowering large herb up to 5m wide with...             Endangered
# 2   Known only from Vic on basalt plains north and...             Endangered
# 3   Only one known remaining population to the nor...             Endangered
# 4   Vic distribution from only three areas in cent...             Endangered
# 5   Known from NSW, ACT, Vic and Tas. Distribution...             Endangered
# 6   Endemic to south-western and central Vic. Stun...  Critically Endangered
# 7   Endemic to south-western Vic, known from only ...             Endangered
# 8   Distributed in Vic and far south- eastern SA. ...             Endangered
# 9   Known only from western Vic. Slender orchid to...             Endangered
# 10  Endemic to central Vic from only a few populat...             Endangered
# 11  Distributed in south-eastern NSW and ACT and s...             Endangered
#
#                                      FLOWERING_PERIOD  \
# 0                Flowers between october and february
# 1   Flowering large herb up to 5m wide with flower...
# 2                  Flowering in september and october
# 3             Flowering mid-october to early november
# 4                 Flowering from december to february
# 5                         Flowers in spring to summer
# 6                          Flowers in april to august
# 7                      Flowering december to february
# 8                       Flowering october to december
# 9                      Flowering october and november
# 10                      Flowering november to january
# 11                       Flowering october to january
#
#                                        HABITAT
# 0          Woodland - Grassy Eucalypt Woodland
# 1   Tussock Plains - lowland tussock grassland
# 2        Rocky areas - Western (Basalt) Plains
# 3   Tussock Plains - lowland tussock grassland
# 4        Rocky areas - Western (Basalt) Plains
# 5   Tussock Plains - lowland tussock grassland
# 6   Tussock Plains - lowland tussock grassland
# 7   Tussock Plains - lowland tussock grassland
# 8   Tussock Plains - lowland tussock grassland
# 9   Tussock Plains - lowland tussock grassland
# 10       Rocky areas - Western (Basalt) Plains
# 11  Tussock Plains - lowland tussock grassland

# %%
# insert the habitat columns
flora.loc[1,"HABITAT"] = "Woodland - Grassy Eucalypt Woodland"
flora.loc[3,"HABITAT"] = "Rocky areas - Western (Basalt) Plains"
flora.loc[7,"HABITAT"] = "Wetland - seasonal herbaceous wetlands"
flora.loc[8,"HABITAT"] = "Wetland - seasonal herbaceous wetlands"
flora.loc[9,"HABITAT"] = "Woodland - Grassy Eucalypt Woodland"
flora.loc[11,"HABITAT"] = "Rocky areas - Western (Basalt) Plains"
flora
# Out:
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Cullen parvum
# 1    Flora                           Dianella amoena
# 2    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 3    Flora                     Diuris fragrantissima
# 4    Flora                     Lepidium hyssopifolium
# 5    Flora      Leucochrysum albicans var. tricolor
# 6    Flora        Pimelea spinescens subsp. spinescens
# 7    Flora                  Prasophyllum diversiflorum
# 8    Flora                      Prasophyllum frenchii
# 9    Flora                      Prasophyllum suaveolens
# 10   Flora                       Pterostylis basaltica
# 11   Flora                 Rutidosis leptorrhynchoides
#
#                                           COMMON_NAME  \
# 0                                 Small Scurf-Pea
# 1                                Matted Flax-Lily
# 2                               Clumping Golden Moths
# 3   Sunshine Diuris, White Diuris, Fragrant Double...
# 4                              Basalt Pepper-Cress
# 5                                  Hoary Sunray
# 6   Plains Rice-Flower, Spiny Rice-Flower, Prickly...
# 7                                Gorae Leek-Orchid
# 8   Maroon Leek-Orchid, Slaty Leek-Orchid, Stout L...
# 9                              Fragrant Leek-Orchid
# 10                                 Basalt Greenhood
# 11                              Button Wrinklewort
#
#                                                 NOTES        EPBC_ACT_STATUS  \
# 0   Only occurs in Vic and SA in grassland and gra...             Endangered
# 1   Summer flowering large herb up to 5m wide with...             Endangered
# 2   Known only from Vic on basalt plains north and...             Endangered
# 3   Only one known remaining population to the nor...             Endangered
# 4   Vic distribution from only three areas in cent...             Endangered
# 5   Known from NSW, ACT, Vic and Tas. Distribution...             Endangered
# 6   Endemic to south-western and central Vic. Stun...  Critically Endangered
# 7   Endemic to south-western Vic, known from only ...             Endangered
# 8   Distributed in Vic and far south- eastern SA. ...             Endangered
# 9   Known only from western Vic. Slender orchid to...             Endangered
# 10  Endemic to central Vic from only a few populat...             Endangered
# 11  Distributed in south-eastern NSW and ACT and s...             Endangered
#
#                                      FLOWERING_PERIOD  \
# 0                Flowers between october and february
# 1   Flowering large herb up to 5m wide with flower...
# 2                  Flowering in september and october
# 3             Flowering mid-october to early november
# 4                 Flowering from december to february
# 5                         Flowers in spring to summer
# 6                          Flowers in april to august
# 7                      Flowering december to february
# 8                       Flowering october to december
# 9                      Flowering october and november
# 10                      Flowering november to january
# 11                       Flowering october to january
#
#                                        HABITAT
# 0          Woodland - Grassy Eucalypt Woodland
# 1          Woodland - Grassy Eucalypt Woodland
# 2        Rocky areas - Western (Basalt) Plains
# 3        Rocky areas - Western (Basalt) Plains
# 4        Rocky areas - Western (Basalt) Plains
# 5   Tussock Plains - lowland tussock grassland
# 6   Tussock Plains - lowland tussock grassland
# 7       Wetland - seasonal herbaceous wetlands
# 8       Wetland - seasonal herbaceous wetlands
# 9          Woodland - Grassy Eucalypt Woodland
# 10       Rocky areas - Western (Basalt) Plains
# 11       Rocky areas - Western (Basalt) Plains

# %%
# create the flowering period column
flora.loc[0,'FLOWERING_PERIOD'] = "From October to February"
flora.loc[1,'FLOWERING_PERIOD'] = "From December to February"
flora.loc[2,'FLOWERING_PERIOD'] = "From September to October"
flora.loc[3,'FLOWERING_PERIOD'] = "From October to November"
flora.loc[4,'FLOWERING_PERIOD'] = "From December to February"
flora.loc[5,'FLOWERING_PERIOD'] = "From September to February"
flora.loc[6,'FLOWERING_PERIOD'] = "From April to August"
flora.loc[7,'FLOWERING_PERIOD'] = "From December to February"
flora.loc[8,'FLOWERING_PERIOD'] = "From October to December"
flora.loc[9,'FLOWERING_PERIOD'] = "From October to November"
flora.loc[10,'FLOWERING_PERIOD'] = "From November to January"
flora.loc[11,'FLOWERING_PERIOD'] = "From October to January"
flora
# Out:
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Cullen parvum
# 1    Flora                           Dianella amoena
# 2    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 3    Flora                     Diuris fragrantissima
# 4    Flora                     Lepidium hyssopifolium
# 5    Flora      Leucochrysum albicans var. tricolor
# 6    Flora        Pimelea spinescens subsp. spinescens
# 7    Flora                  Prasophyllum diversiflorum
# 8    Flora                      Prasophyllum frenchii
# 9    Flora                      Prasophyllum suaveolens
# 10   Flora                       Pterostylis basaltica
# 11   Flora                 Rutidosis leptorrhynchoides
#
#                                           COMMON_NAME  \
# 0                                 Small Scurf-Pea
# 1                                Matted Flax-Lily
# 2                               Clumping Golden Moths
# 3   Sunshine Diuris, White Diuris, Fragrant Double...
# 4                              Basalt Pepper-Cress
# 5                                  Hoary Sunray
# 6   Plains Rice-Flower, Spiny Rice-Flower, Prickly...
# 7                                Gorae Leek-Orchid
# 8   Maroon Leek-Orchid, Slaty Leek-Orchid, Stout L...
# 9                              Fragrant Leek-Orchid
# 10                                 Basalt Greenhood
# 11                              Button Wrinklewort
#
#                                                 NOTES        EPBC_ACT_STATUS  \
# 0   Only occurs in Vic and SA in grassland and gra...             Endangered
# 1   Summer flowering large herb up to 5m wide with...             Endangered
# 2   Known only from Vic on basalt plains north and...             Endangered
# 3   Only one known remaining population to the nor...             Endangered
# 4   Vic distribution from only three areas in cent...             Endangered
# 5   Known from NSW, ACT, Vic and Tas. Distribution...             Endangered
# 6   Endemic to south-western and central Vic. Stun...  Critically Endangered
# 7   Endemic to south-western Vic, known from only ...             Endangered
# 8   Distributed in Vic and far south- eastern SA. ...             Endangered
# 9   Known only from western Vic. Slender orchid to...             Endangered
# 10  Endemic to central Vic from only a few populat...             Endangered
# 11  Distributed in south-eastern NSW and ACT and s...             Endangered
#
#               FLOWERING_PERIOD                                     HABITAT
# 0     From October to February         Woodland - Grassy Eucalypt Woodland
# 1    From December to February         Woodland - Grassy Eucalypt Woodland
# 2    From September to October       Rocky areas - Western (Basalt) Plains
# 3     From October to November       Rocky areas - Western (Basalt) Plains
# 4    From December to February       Rocky areas - Western (Basalt) Plains
# 5   From September to February  Tussock Plains - lowland tussock grassland
# 6         From April to August  Tussock Plains - lowland tussock grassland
# 7    From December to February      Wetland - seasonal herbaceous wetlands
# 8     From October to December      Wetland - seasonal herbaceous wetlands
# 9     From October to November         Woodland - Grassy Eucalypt Woodland
# 10    From November to January       Rocky areas - Western (Basalt) Plains
# 11     From October to January       Rocky areas - Western (Basalt) Plains

# %%
flora.columns.tolist()
# Out:
# ['SPECIES',
#  'SCIENTIFIC_NAME',
#  'COMMON_NAME',
#  'NOTES',
#  'EPBC_ACT_STATUS',
#  'FLOWERING_PERIOD',
#  'HABITAT']

# %%
# formatting the table
new_row1 = {'SPECIES':'Flora', 'SCIENTIFIC_NAME':'Senecio pterophorus', \
           'COMMON_NAME':'African Daisy', 'NOTES':"African daisy is a strong competitor in natural environments and forms dense thickets that exclude native plant species, resulting in a reduction in habitat.", \
          'EPBC_ACT_STATUS':"Secured", 'FLOWERING_PERIOD': "From November to March", \
          'HABITAT': "Woodland - Grassy Eucalypt Woodland"}
flora = flora.append(new_row1, ignore_index=True)
new_row2 = {'SPECIES':'Flora', 'SCIENTIFIC_NAME':'Pennisetum macrourum Trin', \
           'COMMON_NAME':'African feather grass', 'NOTES':"African feather grass is an aggressive invader and often competes and displaces riparian vegetation.", \
          'EPBC_ACT_STATUS':"Secured", 'FLOWERING_PERIOD': "From November to February", \
          'HABITAT': "Wetland - seasonal herbaceous wetlands"}
flora = flora.append(new_row2, ignore_index=True)
new_row3 = {'SPECIES':'Flora', 'SCIENTIFIC_NAME':'Rubus fruticosus', \
           'COMMON_NAME':'Blackberry', 'NOTES':"Blackberry is considered a serious environmental threat and is highly invasive. It can provide harbour and a food source for pest species, as well as serve to outcompete and eliminate other vegetation by excluding light from the soil surface.", \
          'EPBC_ACT_STATUS':"Secured", 'FLOWERING_PERIOD': "From November to January", \
          'HABITAT': "Woodland - Grassy Eucalypt Woodland"}
flora = flora.append(new_row3, ignore_index=True)

new_row4 = {'SPECIES':'Flora', 'SCIENTIFIC_NAME':'Acroptilon repens', \
           'COMMON_NAME':'Hardheads', 'NOTES':"Hardheads are one of the most competitive of all weeds. They can virtually exclude all other vegetation and reduce yield in dry land cropping by as much as 80%.", \
          'EPBC_ACT_STATUS':"Secured", 'FLOWERING_PERIOD': "From November to February", \
          'HABITAT': "Rocky areas - Western (Basalt) Plains"}
flora = flora.append(new_row4, ignore_index=True)

new_row5 = {'SPECIES':'Flora', 'SCIENTIFIC_NAME':'Scolymus hispanicus', \
           'COMMON_NAME':'Golden thistle', 'NOTES':"The stout spines of the golden thistle are present for much of the year and may injure animals.", \
          'EPBC_ACT_STATUS':"Secured", 'FLOWERING_PERIOD': "From November to February", \
          'HABITAT': "Rocky areas - Western (Basalt) Plains"}
flora = flora.append(new_row5, ignore_index=True)

new_row6 = {'SPECIES':'Flora', 'SCIENTIFIC_NAME':'Opuntia robusta', \
           'COMMON_NAME':'Wheel cactus', 'NOTES':"Being long-lived, patches of the plant also provide effective and permanent harbour for pest animals such as rabbits.", \
          'EPBC_ACT_STATUS':"Secured", 'FLOWERING_PERIOD': "From October to November", \
          'HABITAT': "Rocky areas - Western (Basalt) Plains"}
flora = flora.append(new_row6, ignore_index=True)

flora
# Out:
#    SPECIES                               SCIENTIFIC_NAME  \
# 0    Flora                             Cullen parvum
# 1    Flora                           Dianella amoena
# 2    Flora  Diuris sp. aff. chryseopsis (Basalt Plains)
# 3    Flora                     Diuris fragrantissima
# 4    Flora                     Lepidium hyssopifolium
# 5    Flora      Leucochrysum albicans var. tricolor
# 6    Flora        Pimelea spinescens subsp. spinescens
# 7    Flora                  Prasophyllum diversiflorum
# 8    Flora                      Prasophyllum frenchii
# 9    Flora                      Prasophyllum suaveolens
# 10   Flora                       Pterostylis basaltica
# 11   Flora                 Rutidosis leptorrhynchoides
# 12   Flora                       Senecio pterophorus DC.
# 13   Flora                           Senecio pterophorus
# 14   Flora                     Pennisetum macrourum Trin
# 15   Flora                              Rubus fruticosus
# 16   Flora                             Acroptilon repens
# 17   Flora                           Scolymus hispanicus
# 18   Flora                               Opuntia robusta
#
#                                           COMMON_NAME  \
# 0                                 Small Scurf-Pea
# 1                                Matted Flax-Lily
# 2                               Clumping Golden Moths
# 3   Sunshine Diuris, White Diuris, Fragrant Double...
# 4                              Basalt Pepper-Cress
# 5                                  Hoary Sunray
# 6   Plains Rice-Flower, Spiny Rice-Flower, Prickly...
# 7                                Gorae Leek-Orchid
# 8   Maroon Leek-Orchid, Slaty Leek-Orchid, Stout L...
# 9                              Fragrant Leek-Orchid
# 10                                 Basalt Greenhood
# 11                              Button Wrinklewort
# 12                                      African Daisy
# 13                                      African Daisy
# 14                              African feather grass
# 15                                         Blackberry
# 16                                          Hardheads
# 17                                     Golden thistle
# 18                                       Wheel cactus
#
#                                                 NOTES        EPBC_ACT_STATUS  \
# 0   Only occurs in Vic and SA in grassland and gra...             Endangered
# 1   Summer flowering large herb up to 5m wide with...             Endangered
# 2   Known only from Vic on basalt plains north and...             Endangered
# 3   Only one known remaining population to the nor...             Endangered
# 4   Vic distribution from only three areas in cent...             Endangered
# 5   Known from NSW, ACT, Vic and Tas. Distribution...             Endangered
# 6   Endemic to south-western and central Vic. Stun...  Critically Endangered
# 7   Endemic to south-western Vic, known from only ...             Endangered
# 8   Distributed in Vic and far south- eastern SA. ...             Endangered
# 9   Known only from western Vic. Slender orchid to...             Endangered
# 10  Endemic to central Vic from only a few populat...             Endangered
# 11  Distributed in south-eastern NSW and ACT and s...             Endangered
# 12  African daisy is a strong competitor in natura...                Secured
# 13  African daisy is a strong competitor in natura...                Secured
# 14  African feather grass is an aggressive invader...                Secured
# 15  Blackberry is considered a serious environment...                Secured
# 16  Hardheads are one of the most competitive of a...                Secured
# 17  The stout spines of the golden thistle are pre...                Secured
# 18  Being long-lived, patches of the plant also pr...                Secured
#
#               FLOWERING_PERIOD                                     HABITAT
# 0     From October to February         Woodland - Grassy Eucalypt Woodland
# 1    From December to February         Woodland - Grassy Eucalypt Woodland
# 2    From September to October       Rocky areas - Western (Basalt) Plains
# 3     From October to November       Rocky areas - Western (Basalt) Plains
# 4    From December to February       Rocky areas - Western (Basalt) Plains
# 5   From September to February  Tussock Plains - lowland tussock grassland
# 6         From April to August  Tussock Plains - lowland tussock grassland
# 7    From December to February      Wetland - seasonal herbaceous wetlands
# 8     From October to December      Wetland - seasonal herbaceous wetlands
# 9     From October to November         Woodland - Grassy Eucalypt Woodland
# 10    From November to January       Rocky areas - Western (Basalt) Plains
# 11     From October to January       Rocky areas - Western (Basalt) Plains
# 12      From November to March         Woodland - Grassy Eucalypt Woodland
# 13      From November to March         Woodland - Grassy Eucalypt Woodland
# 14   From November to February      Wetland - seasonal herbaceous wetlands
# 15    From November to January         Woodland - Grassy Eucalypt Woodland
# 16   From November to February       Rocky areas - Western (Basalt) Plains
# 17   From November to February       Rocky areas - Western (Basalt) Plains
# 18    From October to November       Rocky areas - Western (Basalt) Plains

# %%
# output the table as csv file
flora.to_csv('Flora-Checklist1.csv')
